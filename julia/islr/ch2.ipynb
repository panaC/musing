# %%
io = open("College.csv", "r");

# %%
read(io, String)
# Out:
# ",Private,Apps,Accept,Enroll,Top10perc,Top25perc,F.Undergrad,P.Undergrad,Outstate,Room.Board,Books,Personal,PhD,Terminal,S.F.Ratio,perc.alumni,Expend,Grad.Rate\nAbilene Christian University,Yes,1660,1232,721,23,52,2885,537,7440,3300,450,2200,70,78,18.1,12,7041,60\nAdelphi University,Yes,2186,1924,512,16,29,2683,1227,12280,6450,750,1500,29,30,12.2,16,10527,56\nAdrian College,Yes,1428,1097,336,22,50,1036,99,11250,3750,400,1165,53,66,12.9,30,8735,54\nAgnes Scott College,Yes,417,349,137,60,89,510,63,12960,5450,450,875,92,97,7.7,37,19016,59\nAlaska Pacific University,Yes,193,146,55,16,44,249,869,7560,4120,800,1500,76,72,11.9,2,10922,15\nAlbertson College,Yes,587,479,158,38,62,678,41,13500,3335,500,675,67,73,9.4,11,9727,55\nAlbertus Magnus College,Yes,353,340,103,17,45,416,230,13290,5720,500,1500,90,93,11.5,26,8861,63\nAlbion College,Yes,1899,1720,489,37,68,1594,32,13868,4826,450,850,89,100,13.7,37,11487,73\nAlbright College,Yes,1038,839,227,30,63,973,306,15595,4400,300,500,79,84,11.3,23,1
# ...

# %%
using DataFrames, CSV, Plots, StatsPlots

# %%
data = CSV.File("College.csv") |> DataFrame
# Out:
# 777×19 DataFrame
#  Row │ Column1                            Private  Apps   Accept  Enroll  Top1 ⋯
#      │ String                             String   Int64  Int64   Int64   Int6 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ Abilene Christian University       Yes       1660    1232     721       ⋯
#    2 │ Adelphi University                 Yes       2186    1924     512
#    3 │ Adrian College                     Yes       1428    1097     336
#    4 │ Agnes Scott College                Yes        417     349     137
#    5 │ Alaska Pacific University          Yes        193     146      55       ⋯
#    6 │ Albertson College                  Yes        587     479     158
#    7 │ Albertus Magnus College            Yes        353     340     103
#    8 │ Albion College                     Yes       1899    1720     489
#    9 │ Albright College                   Yes       1038     839     227       ⋯
# ...

# %%
plot([sin,cos], 0, π)

# %%
data[!, "Private"]
# Out:
# 777-element PooledArrays.PooledVector{String, UInt32, Vector{UInt32}}:
#  "Yes"
#  "Yes"
#  "Yes"
#  "Yes"
#  "Yes"
#  "Yes"
#  "Yes"
#  "Yes"
#  "Yes"
#  "Yes"
#  "Yes"
#  "Yes"
#  "Yes"
#  ⋮
#  "Yes"
#  "No"
#  "No"
#  "Yes"
#  "Yes"
#  "Yes"
#  "Yes"
#  "No"
#  "Yes"
#  "Yes"
#  "Yes"
#  "Yes"

# %%
data[!, "Outstate"]
# Out:
# 777-element Vector{Int64}:
#   7440
#  12280
#  11250
#  12960
#   7560
#  13500
#  13290
#  13868
#  15595
#  10468
#  16548
#  17080
#   9690
#      ⋮
#   7820
#   4200
#   6400
#   9100
#  15948
#  12680
#  15884
#   6797
#  11520
#   6900
#  19840
#   4990

# %%
boxplot(data[!, "Private"], data[!, "Outstate"])
